# %% [markdown]
# # Convert embeddings models from text to binary

# %%
from gensim.models import KeyedVectors

# Load the model in text format (slow, one-time operation)
model = KeyedVectors.load_word2vec_format("../data/external/embeddings/itwiki_20180420_100d.txt", binary=False)

# Save the model in binary format
model.save("../data/external/embeddings/itwiki_20180420_100d.bin")

# %%
model = KeyedVectors.load("../data/external/embeddings/enwiki_20180420_100d.bin", mmap='r')

# %%
model.most_similar(positive=["truck"])
# Out:
# [('trucks', 0.8690112829208374),
#  ('car', 0.8125396370887756),
#  ('ENTITY/Pickup_truck', 0.7950857281684875),
#  ('forklift', 0.792870044708252),
#  ('lorry', 0.7901115417480469),
#  ('ENTITY/Semi-trailer_truck', 0.7845458388328552),
#  ('vehicle', 0.7816139459609985),
#  ('jeep', 0.7799525856971741),
#  ('wc52', 0.778714120388031),
#  ('g506', 0.7757207155227661)]
