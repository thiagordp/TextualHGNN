# %% [markdown]
# # Convert embeddings models from text to binary

# %%
from gensim.models import KeyedVectors

# %%
# Load the model in text format (slow, one-time operation)
model = KeyedVectors.load_word2vec_format("../data/external/embeddings/enwiki_20180420_100d.txt", binary=False)

# Save the model in binary format
model.save("../data/external/embeddings/enwiki_20180420_100d.bin")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Software/anaconda3/envs/phd_env/lib/python3.10/site-packages/gensim/utils.py:763, in SaveLoad.save(self, fname_or_handle, separately, sep_limit, ignore, pickle_protocol)
#     762 try:
# --> 763     _pickle.dump(self, fname_or_handle, protocol=pickle_protocol)
#     764     logger.info("saved %s object", self.__class__.__name__)
#
# TypeError: file must have a 'write' attribute
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 5
#       2 model = KeyedVectors.load_word2vec_format("../data/external/embeddings/enwiki_20180420_100d.txt", binary=False)
#       4 # Save the model in binary format
# ----> 5 model.save("../data/external/embeddings/enwiki_20180420_100d.bin")
#
# ...

# %%
model = KeyedVectors.load("../data/external/embeddings/enwiki_20180420_100d.bin", mmap='r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model = KeyedVectors.load("../data/external/embeddings/enwiki_20180420_100d.bin", mmap='r')
#
# File ~/Software/anaconda3/envs/phd_env/lib/python3.10/site-packages/gensim/utils.py:485, in SaveLoad.load(cls, fname, mmap)
#     481 logger.info("loading %s object from %s", cls.__name__, fname)
#     483 compress, subname = SaveLoad._adapt_by_suffix(fname)
# --> 485 obj = unpickle(fname)
#     486 obj._load_specials(fname, mmap, compress, subname)
#     487 obj.add_lifecycle_event("loaded", fname=fname)
#
# File ~/Software/anaconda3/envs/phd_env/lib/python3.10/site-packages/gensim/utils.py:1459, in unpickle(fname)
#    1445 def unpickle(fname):
#    1446     """Load object from `fname`, using smart_open so that `fname` can be on S3, HDFS, compressed etc.
#    1447
#    1448     Parameters
#    (...)
# ...

# %%
model.most_similar(positive=["casa"])
# Out:
# [('car', 0.7685932517051697),
#  ('m939', 0.7482656240463257),
#  ('iroc', 0.7303648591041565),
#  ('f250', 0.7286450266838074),
#  ('bikes', 0.7262975573539734),
#  ('furgonati', 0.7252516746520996),
#  ('kenworth', 0.72406405210495),
#  ('gpw', 0.7211957573890686),
#  ('powerball', 0.7158700823783875),
#  ('brumos', 0.7127411961555481)]
